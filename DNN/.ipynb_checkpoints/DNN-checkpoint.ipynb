# %% [markdown]
# ### Author:  XU Haohang      Stuid: 22436804

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import torch
from torch import nn
from sklearn.model_selection import cross_validate,KFold
from torch.optim import Adam
import time

# %%
Churn =pd.read_csv('../dataset/processed/BankChurners.csv')
Churn = Churn.drop(Churn.columns[0],axis=1)

# %% [markdown]
# ## Data Analysis

# %%
Churn.describe()
# Out:
#        Attrition_Flag  Customer_Age  Dependent_count  Education_Level  \
# count    10127.000000  10127.000000     10127.000000     10127.000000
# mean         0.839340      0.432467         0.469241         0.413029
# std          0.367235      0.170571         0.259782         0.262117
# min          0.000000      0.000000         0.000000         0.000000
# 25%          1.000000      0.319149         0.200000         0.200000
# 50%          1.000000      0.425532         0.400000         0.400000
# 75%          1.000000      0.553191         0.600000         0.600000
# max          1.000000      1.000000         1.000000         1.000000
#
#        Income_Category  Months_on_book  Total_Relationship_Count  \
# count     10127.000000    10127.000000              10127.000000
# mean          0.309320        0.533219                  0.562516
# std           0.330752        0.185731                  0.310882
# min           0.000000        0.000000                  0.000000
# ...

# %%
Churn['Attrition_Flag'].plot.hist(bins=2, alpha=1)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
corr = Churn.corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Model Building

# %%
class dnn(nn.Module):
    def __init__(self, input_dim, output_dim):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_dim,30),    
            nn.ReLU(),  
            nn.Linear(30,20),
            nn.ReLU(), 
            nn.Linear(20,20),
            nn.ReLU(), 
            nn.Linear(20,15),
            nn.ReLU(), 
            nn.Linear(15,output_dim),
            nn.Sigmoid()
            )
    def forward(self, x):
        x = x.view(x.shape[0], -1)
        return self.layers(x)

# %%
dnn = dnn(26,1)

# %%
loss = torch.nn.BCELoss()
optimizer = torch.optim.SGD(dnn.parameters(),
                            lr=0.01,   #0.5,0.1,0.05,0.01
                            weight_decay=0.002,  
                            momentum=0.9)
#optimizer = torch.optim.Adam(dnn.parameters(), lr=0.01)
#optimizer = torch.optim.Adagrad(dnn.parameters(), lr=0.01)

# %%
class ChurnDataset(torch.utils.data.Dataset):
    def __init__(self,churnpd):
        churn=churnpd.copy()
 
        x=churn[Churn.columns[1:]].values
        y=churn.Attrition_Flag.values
 
        self.x_train=torch.tensor(x,dtype=torch.float32)
        self.y_train=torch.tensor(y,dtype=torch.float32)

    def __len__(self):
            
        return len(self.y_train)

    def __getitem__(self,idx):
        return self.x_train[idx],self.y_train[idx]

# %% [markdown]
# ## Model Evaluation

# %%
from torchmetrics.classification import BinaryF1Score
from torchmetrics.classification import BinaryRecall
from torchmetrics.classification import BinaryAUROC
from torchmetrics.classification import BinaryAccuracy
from torchmetrics.classification import BinaryPrecision
from torchmetrics.classification import BinaryROC
from torchmetrics.classification import BinaryConfusionMatrix
F1 = BinaryF1Score()
Rec = BinaryRecall()
AUROC = BinaryAUROC()
Acc  = BinaryAccuracy()
Prec = BinaryPrecision()
ROC = BinaryROC()
Con_Mat = BinaryConfusionMatrix()
ev = pd.DataFrame(columns = ['epoch','Accuracy','Recall','Precision','F1_score','AUROC','time'])

# %%
def plotroc(fpr,tpr,auroc):    
    plt.figure()
    lw = 2
    plt.figure(figsize=(10,10))
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC CURVE')
    plt.plot(fpr.tolist(), tpr.tolist(), color='orange',lw=lw, label='ROC curve (area = %0.3f)' % auroc)
    plt.show()
    return plt
def plotcm(mat):
    plt.matshow(mat.numpy(), cmap=plt.cm.Greens)  
    plt.colorbar()  
    plt.ylabel('True label')  
    plt.xlabel('Predicted label')
    plt.show()
def evaluation(preds,targets,preds_prob,tick):
    f1 = F1(preds,targets).tolist()
    rec = Rec(preds,targets).tolist()
    auroc = AUROC(preds,targets).tolist()
    acc  = Acc(preds,targets).tolist()
    prec = Prec(preds,targets).tolist()
    fpr, tpr, thresholds = ROC(preds_prob,targets)
    con_mat = Con_Mat(preds,targets)
    tok  = time.time()
    print('*'*80)
    ev.loc[epoch] = [epoch,round(acc,4),round(rec,4),round(prec,4),round(f1,4),round(auroc,4),round((tok-tick),4)]
    print(ev)
    plotroc(fpr,tpr,auroc)
    plotcm(con_mat)

# %% [markdown]
# ## Training&Validation&Tesing

# %%
min_valid_loss = np.inf
begin= time.time()
for epoch in range(30):
    preds = torch.tensor([])
    targets = torch.tensor([])
    preds_prob =  torch.tensor([])
    tick = time.time()
    kf5 = KFold(n_splits=10, shuffle=True)
    for train, test in kf5.split(Churn):
        dnn.train() 
        trainset = Churn.iloc[train].copy()
        testset  = Churn.iloc[test].copy()
        trDataset = ChurnDataset(trainset)
        teDataset = ChurnDataset(testset)
        train, valid = torch.utils.data.random_split(trDataset,[trainset.shape[0]-int(trainset.shape[0]/5),int(trainset.shape[0]/5)])
        validloader = torch.utils.data.DataLoader(valid, batch_size=128, shuffle=True)
        trainloader = torch.utils.data.DataLoader(trDataset, batch_size=128, shuffle=True)
        testloader =  torch.utils.data.DataLoader(teDataset, batch_size=128, shuffle=True)
        for x,y in trainloader:
            optimizer.zero_grad() 
            output = dnn(x)  
            new_loss = loss(output.view(-1), y)  
            new_loss.backward() 
            optimizer.step()
        dnn.eval()
        valid_loss = 0.0
        for data, labels in validloader:            
            target = dnn(data)
            lossvalue = loss(target.view(-1),labels)
            valid_loss += lossvalue.item()        
        if min_valid_loss > valid_loss:            
            min_valid_loss = valid_loss
            torch.save(dnn.state_dict(), 'best_model')
        dnn.eval() 
        torch.load('best_model')
        with torch.no_grad():
            for x,y in testloader:
                output = dnn(x) 
                preds_prob =torch.cat((preds_prob,output.view(-1)))
                output[output>0.5] = 1
                output[output<=0.5] = 0
                res_lbl = output.view(-1)
                preds = torch.cat((preds,res_lbl))
                targets = torch.cat((targets,y))
    evaluation(preds,targets,preds_prob,tick)
end= time.time()
print(f'total cost {(end-begin)} s')
# Out:
# ********************************************************************************
#    epoch  Accuracy  Recall  Precision  F1_score  AUROC    time
# 0    0.0    0.8393     1.0     0.8393    0.9127    0.5  1.1149
# ********************************************************************************
#    epoch  Accuracy  Recall  Precision  F1_score   AUROC    time
# 0    0.0    0.8393  1.0000     0.8393    0.9127  0.5000  1.1149
# 1    1.0    0.8895  0.9828     0.8957    0.9372  0.6924  1.0162
# ********************************************************************************
#    epoch  Accuracy  Recall  Precision  F1_score   AUROC    time
# 0    0.0    0.8393  1.0000     0.8393    0.9127  0.5000  1.1149
# 1    1.0    0.8895  0.9828     0.8957    0.9372  0.6924  1.0162
# 2    2.0    0.9119  0.9702     0.9281    0.9487  0.7887  1.1008
# ********************************************************************************
#    epoch  Accuracy  Recall  Precision  F1_score   AUROC    time
# ...

# %%
input_names = ["Churn"]
output_names = ["Churn Prediction"]
torch.onnx.export(dnn, xinput, "dnn.onnx", input_names=input_names, output_names=output_names)

# %%
ev
# Out:
#     epoch  Accuracy  Recall  Precision  F1_score   AUROC    time
# 0     0.0    0.8393  1.0000     0.8393    0.9127  0.5000  1.1149
# 1     1.0    0.8895  0.9828     0.8957    0.9372  0.6924  1.0162
# 2     2.0    0.9119  0.9702     0.9281    0.9487  0.7887  1.1008
# 3     3.0    0.9244  0.9676     0.9437    0.9555  0.8329  1.1126
# 4     4.0    0.9289  0.9778     0.9399    0.9585  0.8257  1.1101
# 5     5.0    0.9320  0.9720     0.9482    0.9600  0.8474  1.0926
# 6     6.0    0.9340  0.9767     0.9464    0.9613  0.8439  1.0828
# 7     7.0    0.9349  0.9679     0.9552    0.9615  0.8653  1.1025
# 8     8.0    0.9335  0.9672     0.9543    0.9607  0.8625  1.0572
# 9     9.0    0.9406  0.9687     0.9608    0.9647  0.8811  1.0650
# 10   10.0    0.9356  0.9724     0.9520    0.9621  0.8580  1.1105
# 11   11.0    0.9379  0.9720     0.9548    0.9633  0.8658  1.0831
# 12   12.0    0.9416  0.9766     0.9549    0.9656  0.8678  1.0835
# ...

# %%
ev.to_csv('result.csv')
