# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('BankChurners.csv')

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
df.shape
# Out:
# (10127, 23)

# %%
df = df.drop(columns=['CLIENTNUM','Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1','Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'])

# %%
df.describe()
# Out:
#        Customer_Age  Dependent_count  Months_on_book  \
# count  10127.000000     10127.000000    10127.000000
# mean      46.325960         2.346203       35.928409
# std        8.016814         1.298908        7.986416
# min       26.000000         0.000000       13.000000
# 25%       41.000000         1.000000       31.000000
# 50%       46.000000         2.000000       36.000000
# 75%       52.000000         3.000000       40.000000
# max       73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# ...

# %% [markdown]
# # Bar Chart of Attrition Flag

# %%
df['Attrition_Flag'].value_counts()
# Out:
# Existing Customer    8500
# Attrited Customer    1627
# Name: Attrition_Flag, dtype: int64

# %%
sns.countplot(df['Attrition_Flag']).set(title='Bar Chat of Attrition Flag');

# %% [markdown]
# # Histogram of Customer Age

# %%
sns.distplot(df['Customer_Age']).set(title='Histogram of Customer Age');

# %% [markdown]
# # Pie Chart of Gender Distribution

# %%
Female,Male = df['Gender'].value_counts()
plt.pie([Female,Male], explode=(0.05,0),labels=['Female', 'male'],
        colors=['#009ACD', '#ADD8E6'],autopct='%1.2f%%');

# %% [markdown]
# # Bar Chat of Education Level

# %%
df['Education_Level'].value_counts()
# Out:
# Graduate         3128
# High School      2013
# Unknown          1519
# Uneducated       1487
# College          1013
# Post-Graduate     516
# Doctorate         451
# Name: Education_Level, dtype: int64

# %%
sns.countplot(df['Education_Level']).set(title='Bar Chat of Education Level');

# %% [markdown]
# # Scatter Plot of Customer Age & Credit Limit with Fitted Line

# %%
sns.scatterplot(data=df, x='Customer_Age',y='Credit_Limit').set(title='Scatter Plot of Customer Age & Credit Limit');

# %% [markdown]
# # Distribution of Card Category Respect to Income

# %%
print(df['Card_Category'].value_counts())
# Out:
# Blue        9436
# Silver       555
# Gold         116
# Platinum      20
# Name: Card_Category, dtype: int64

# %%
sns.countplot(data = df,x='Card_Category',
              hue='Income_Category').set(title='Distribution of Card Category Respect to Income');

# %% [markdown]
# # Heatmap of Numerical Dataset

# %%
df_numerical = df.loc[:,df.dtypes != np.object]
corr = df_numerical.corr()
plt.figure(figsize=[15,15])
plt.rcParams['font.size']=10
sns.heatmap(corr, cmap='YlGnBu', annot= True, linewidths=0.5 );

# %%
df_num_float = df.select_dtypes(include = ['float64']) #float variables
df_num_float['a_flag'],df_num_float['revolving_balance'], df_num_float['total_trans_amt'], df_num_float['total_trans_count'] = df['Attrition_Flag'], df['Total_Revolving_Bal'], df['Total_Trans_Amt'], df['Total_Trans_Ct']
sns.pairplot(df_num_float, hue='a_flag', palette='magma');

# %% [markdown]
# # Linear Regression of Numerical Dataset

# %%
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import KFold
from sklearn.decomposition import PCA


df_processed = pd.read_csv('BankChurners_processed.csv')
df_numerical_processed = df_processed.loc[:,df_processed.dtypes != np.object]


col = df_numerical.columns.values.tolist()
col.remove('Credit_Limit')

X = df_numerical[col]
y= df_numerical['Credit_Limit']
score=0
n=5
kf = KFold(n_splits=n, shuffle=False)
for train_index, test_index in kf.split(X):
    X_train, X_test = X.values[train_index], X.values[test_index]
    y_train, y_test = y.values[train_index], y.values[test_index]
    lr = LinearRegression().fit(X_train, y_train)
    print('The coefficients:')
    print(lr.coef_)
    print('The intercept:')
    print(lr.intercept_)
    score+=lr.score(X_train,y_train)
print('The R-squared is ',score/n,', it means ','{0:.0f}%'.format(score/n * 100),'Credit Limit can be explained by this model')
   
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]

print(vif_data)
# Out:
# The coefficients:
# [-1.26668156e-13 -9.25232113e-14  1.38967830e-13  6.43827539e-13
#   9.09191478e-14  2.57707065e-13  1.00000000e+00  1.00000000e+00
#   7.42354762e-13  4.85722573e-16 -3.52083813e-15  8.88278243e-14
#  -1.79480552e-13]
# The intercept:
# 2.1827872842550278e-11
# The coefficients:
# [-1.29804939e-13 -2.04336548e-13  1.26678182e-13 -9.59529731e-14
#  -2.18488937e-13  2.60226478e-14  1.00000000e+00  1.00000000e+00
#   1.48188778e-13  5.55111512e-16 -6.74807432e-16 -1.97945522e-15
#   2.73505002e-13]
# The intercept:
# 0.0
# The coefficients:
# [ 1.67731651e-14  1.02536035e-13 -2.82434666e-15  4.22242645e-13
#  -1.82239865e-13  3.44091442e-13  1.00000000e+00  1.00000000e+00
#  -1.69656795e-12 -7.63278329e-16  1.21511958e-15  3.54921460e-13
#   2.87990460e-13]
# The intercept:
# 8.36735125631094e-11
# The coefficients:
# [-1.34050026e-13 -2.21748618e-13  1.71823866e-13  7.59442451e-13
#  -1.10718120e-13 -6.84958529e-15  1.00000000e+00  1.00000000e+00
# ...

# %%
need_to_remove = ['Customer_Age','Months_on_book','Total_Amt_Chng_Q4_Q1','Total_Trans_Ct'] # Remove parameters which VIF > 10
for i in need_to_remove:
    col.remove(i)
X = df_numerical[col]
y= df_numerical['Credit_Limit']
score=0
n=2
kf = KFold(n_splits=n, shuffle=False)
for train_index, test_index in kf.split(X):
    X_train, X_test = X.values[train_index], X.values[test_index]
    y_train, y_test = y.values[train_index], y.values[test_index]
    lr = LinearRegression().fit(X_train, y_train)
    print(lr.coef_)
    print(lr.intercept_)
    score+=lr.score(X_train,y_train)
print('The R-squared is ',score/n,', it means ','{0:.0f}%'.format(score/n * 100),'Credit Limit can be explained by this model')
   
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]

print(vif_data)
# Out:
# [ 1.37156050e-13 -1.48436818e-12 -1.59328814e-12 -7.76075164e-13
#   1.00000000e+00  1.00000000e+00 -1.11022302e-16 -8.94459310e-13
#   6.89121907e-13]
# -1.2732925824820995e-11
# [-2.47986343e-13 -2.06279438e-13 -1.19635198e-13 -1.01395475e-13
#   1.00000000e+00  1.00000000e+00 -1.38777878e-16 -2.50724566e-12
#   5.70905546e-13]
# 2.3646862246096134e-11
# The R-squared is  1.0 , it means  100% Credit Limit can be explained by this model
#                     feature       VIF
# 0           Dependent_count  3.881326
# 1  Total_Relationship_Count  6.324863
# 2    Months_Inactive_12_mon  5.353107
# 3     Contacts_Count_12_mon  5.000439
# 4       Total_Revolving_Bal  6.227298
# 5           Avg_Open_To_Buy  2.874079
# 6           Total_Trans_Amt  2.832461
# 7       Total_Ct_Chng_Q4_Q1  8.123846
# 8     Avg_Utilization_Ratio  5.600453

# %%
from sklearn import preprocessing
from sklearn import decomposition
from sklearn.decomposition import PCA
pca = decomposition.PCA(n_components = 3)
pca.fit(X)
name=pca.transform(X)
print(name)
# Out:
# [[ 4201.9156643  -3576.00774995  -299.7916817 ]
#  [ -298.31615046 -3104.81174365  -240.21624205]
#  [-4215.97238334 -2243.31240585 -1136.97738459]
#  ...
#  [-1629.17870665  5995.48531062 -1285.29871986]
#  [-1892.41859867  4113.82008236 -1250.08749856]
#  [ 1373.28863964  5820.76617742   691.69687047]]
